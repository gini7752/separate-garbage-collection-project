# %% [markdown]
# # Garbage Classification

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Conv2D, Flatten, MaxPooling2D,Dense,Dropout
from tensorflow.keras.models  import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from tensorflow.compat.v1 import ConfigProto

from tensorflow.compat.v1 import InteractiveSession



config = ConfigProto()

config.gpu_options.allow_growth = True

session = InteractiveSession(config=config)

# %%
tf.__version__
# Out:
# '2.4.0'

# %%
import matplotlib.pyplot as plt
def plot_imgs(item_dir, top=10):
    all_item_dirs = os.listdir(item_dir)
    item_files = [os.path.join(item_dir, file) for file in all_item_dirs][:5]
  
    plt.figure(figsize=(10, 10))
  
    for idx, img_path in enumerate(item_files):
        plt.subplot(5, 5, idx+1)
    
        img = plt.imread(img_path)
        plt.tight_layout()         
        plt.imshow(img, cmap='gray')

# %%
import os
print(os.listdir('./Garbage classification/Garbage classification'))
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
data_path = './Garbage classification/Garbage classification'

# %%
plot_imgs(data_path+'/cardboard')

# %%
plot_imgs(data_path+'/glass')

# %%
plot_imgs(data_path+'/paper')

# %%
plot_imgs(data_path+'/plastic')

# %%
plot_imgs(data_path+'/metal')

# %%
plot_imgs(data_path+'/trash')

# %% [markdown]
# ## Data Generator

# %%
batch_size = 32

# %%
train=ImageDataGenerator(
    horizontal_flip=True, 
    vertical_flip=True,
    validation_split=0.1,
    rescale=1./255,
    shear_range = 0.1,
    zoom_range = 0.1,
    width_shift_range = 0.1,
    height_shift_range = 0.1,)

test=ImageDataGenerator(rescale=1./255,validation_split=0.1)

train_generator=train.flow_from_directory(data_path,target_size=(512,384),batch_size=batch_size,class_mode='categorical',subset='training')

test_generator=test.flow_from_directory(data_path,target_size=(512,384),batch_size=batch_size,class_mode='categorical',subset='validation')
# Out:
# Found 2313 images belonging to 6 classes.
# Found 255 images belonging to 6 classes.

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
print(labels)
# Out:
# {0: 'cardboard', 1: 'glass', 2: 'metal', 3: 'paper', 4: 'plastic', 5: 'trash'}

# %% [markdown]
# ## Build Model

# %%
num_classes = 6

# %%
model = Sequential()
   
model.add(Conv2D(32,(3,3), padding='same', input_shape=(512,384,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2))) 
model.add(Dropout(rate=0.1))
model.add(Conv2D(64,(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(rate=0.1))
model.add(Conv2D(64,(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(rate=0.1))
model.add(Conv2D(32,(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2))) 
model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(num_classes,activation='softmax')) # 다중분류

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 512, 384, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 256, 192, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 256, 192, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 192, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 128, 96, 64)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128, 96, 64)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 96, 64)       36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 64, 48, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64, 48, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 48, 32)        18464
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 24, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 24576)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                1572928
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 1,648,102
# Trainable params: 1,648,102
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ## Train Model

# %%
num_epochs = 50
step_size_train=train_generator.n//train_generator.batch_size
step_size_test =test_generator.n//test_generator.batch_size

# %%
history = model.fit(train_generator, epochs=num_epochs, steps_per_epoch=step_size_train,validation_data=test_generator,
                    validation_steps=step_size_test)
# Out:
# Epoch 1/50
# 72/72 [==============================] - 60s 731ms/step - loss: 1.8659 - accuracy: 0.2102 - val_loss: 1.7283 - val_accuracy: 0.1786
# Epoch 2/50
# 72/72 [==============================] - 53s 733ms/step - loss: 1.7066 - accuracy: 0.2351 - val_loss: 1.5902 - val_accuracy: 0.3482
# Epoch 3/50
# 72/72 [==============================] - 53s 730ms/step - loss: 1.5669 - accuracy: 0.3288 - val_loss: 1.5294 - val_accuracy: 0.3571
# 72/72 [==============================] - 51s 713ms/step - loss: 1.0072 - accuracy: 0.6102 - val_loss: 1.0713 - val_accuracy: 0.6071
# Epoch 23/50
# 72/72 [==============================] - 51s 713ms/step - loss: 1.0009 - accuracy: 0.6272 - val_loss: 1.1178 - val_accuracy: 0.6027
# Epoch 24/50
# 72/72 [==============================] - 52s 716ms/step - loss: 0.9887 - accuracy: 0.6314 - val_loss: 1.1991 - val_accuracy: 0.6116
# Epoch 25/50
# 72/72 [==============================] - 51s 712ms/step - loss: 0.9409 - accuracy: 0.6597 - val_loss: 1.1006 - val_accuracy: 0.6429
# Epoch 26/50
# 72/72 [==============================] - 52s 726ms/step - loss: 0.9519 - accuracy: 0.6671 - val_loss: 1.0122 - val_accuracy: 0.6071
# Epoch 27/50
# 72/72 [==============================] - 52s 724ms/step - loss: 0.8951 - accuracy: 0.6767 - val_loss: 1.1279 - val_accuracy: 0.6071
# Epoch 28/50
# 72/72 [==============================] - 52s 725ms/step - loss: 0.9116 - accuracy: 0.6735 - val_loss: 1.1153 - val_accuracy: 0.6071
# Epoch 29/50
# 72/72 [==============================] - 52s 718ms/step - loss: 0.9095 - accuracy: 0.6607 - val_loss: 1.1396 - val_accuracy: 0.6205
# Epoch 30/50
# 72/72 [==============================] - 52s 717ms/step - loss: 0.8846 - accuracy: 0.6795 - val_loss: 1.1158 - val_accuracy: 0.6339
# Epoch 31/50
# 72/72 [==============================] - 52s 719ms/step - loss: 0.8655 - accuracy: 0.6863 - val_loss: 1.0164 - val_accuracy: 0.6518
# Epoch 32/50
# 72/72 [==============================] - 52s 719ms/step - loss: 0.8226 - accuracy: 0.7134 - val_loss: 1.0134 - val_accuracy: 0.6250
# Epoch 33/50
# 72/72 [==============================] - 52s 721ms/step - loss: 0.8303 - accuracy: 0.7110 - val_loss: 1.1025 - val_accuracy: 0.6562
# Epoch 34/50
# 72/72 [==============================] - 52s 723ms/step - loss: 0.7949 - accuracy: 0.7077 - val_loss: 1.1214 - val_accuracy: 0.6384
# Epoch 35/50
# 72/72 [==============================] - 52s 718ms/step - loss: 0.8575 - accuracy: 0.7037 - val_loss: 1.1025 - val_accuracy: 0.6339
# Epoch 36/50
# 72/72 [==============================] - 52s 715ms/step - loss: 0.7948 - accuracy: 0.7200 - val_loss: 0.9907 - val_accuracy: 0.6518
# Epoch 37/50
# 72/72 [==============================] - 52s 726ms/step - loss: 0.8038 - accuracy: 0.7126 - val_loss: 1.0745 - val_accuracy: 0.6339
# Epoch 38/50
# 72/72 [==============================] - 52s 717ms/step - loss: 0.7515 - accuracy: 0.7314 - val_loss: 1.0493 - val_accuracy: 0.6652
# Epoch 39/50
# 72/72 [==============================] - 52s 714ms/step - loss: 0.7647 - accuracy: 0.7267 - val_loss: 1.0071 - val_accuracy: 0.6562
# Epoch 40/50
# 72/72 [==============================] - 51s 713ms/step - loss: 0.7493 - accuracy: 0.7172 - val_loss: 1.0252 - val_accuracy: 0.6786
# Epoch 41/50
# 72/72 [==============================] - 52s 720ms/step - loss: 0.8019 - accuracy: 0.7146 - val_loss: 1.0477 - val_accuracy: 0.7098
# Epoch 42/50
# 72/72 [==============================] - 52s 719ms/step - loss: 0.7470 - accuracy: 0.7329 - val_loss: 0.9554 - val_accuracy: 0.6964
# Epoch 43/50
# 72/72 [==============================] - 52s 714ms/step - loss: 0.6694 - accuracy: 0.7644 - val_loss: 0.9873 - val_accuracy: 0.6607
# Epoch 44/50
# 72/72 [==============================] - 51s 714ms/step - loss: 0.7208 - accuracy: 0.7446 - val_loss: 1.0149 - val_accuracy: 0.6920
# Epoch 45/50
# 72/72 [==============================] - 52s 714ms/step - loss: 0.6816 - accuracy: 0.7479 - val_loss: 1.0613 - val_accuracy: 0.6875
# Epoch 46/50
# 72/72 [==============================] - 51s 712ms/step - loss: 0.7221 - accuracy: 0.7250 - val_loss: 1.0697 - val_accuracy: 0.6786
# Epoch 47/50
# 72/72 [==============================] - 51s 713ms/step - loss: 0.6577 - accuracy: 0.7600 - val_loss: 1.2902 - val_accuracy: 0.6607
# Epoch 48/50
# 72/72 [==============================] - 51s 712ms/step - loss: 0.6415 - accuracy: 0.7669 - val_loss: 1.0478 - val_accuracy: 0.6652
# Epoch 49/50
# 72/72 [==============================] - 51s 712ms/step - loss: 0.6323 - accuracy: 0.7676 - val_loss: 1.0368 - val_accuracy: 0.6964
# Epoch 50/50
# 72/72 [==============================] - 51s 714ms/step - loss: 0.6642 - accuracy: 0.7682 - val_loss: 0.9360 - val_accuracy: 0.7143

# %% [markdown]
# ## Model save

# %%
model.save('garbage_model3.h5')

# %%
Load_model = keras.models.load_model('garbage_model3.h5')

# %% [markdown]
# ## Evaluate Model

# %%
# Evaluate Model
score = Load_model.evaluate_generator(test_generator, steps=step_size_test)
print(score)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# [1.001380205154419, 0.7142857313156128]

# %% [markdown]
# ## Training History

# %%
# Show Train History
keys=history.history.keys()
print(keys)

def show_train_history(hisData,train,test): 
    plt.plot(hisData.history[train])
    plt.plot(hisData.history[test])
    plt.title('Training History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

show_train_history(history, 'loss', 'val_loss')
show_train_history(history, 'accuracy', 'val_accuracy')
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
image_path = "./Garbage classification/carmea"

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
testGen = train.flow_from_directory(
    os.path.join(image_path),
    target_size=(512,384),
)
# Out:
# Found 6 images belonging to 1 classes.

# %%
predictions = Load_model.predict(testGen)

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import array_to_img

cls_index = ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

count = 5
print(predictions[count])
print('예측 : ', cls_index[np.argmax(predictions[count])], sep="")
# Out:
# [0.6103512  0.03453746 0.0119899  0.07582648 0.08583511 0.18145986]
# 예측 : cardboard

# %%
cls_index = ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

imgs = testGen.next()
arr = imgs[0][0]
img = array_to_img(arr).resize((128, 128))
plt.imshow(img)
result = model.predict_classes(arr.reshape(1, 512, 384, 3))
print('예측: {}'.format(cls_index[result[0]]))
# Out:
# 예측: paper
